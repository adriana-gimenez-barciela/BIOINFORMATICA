# %% [markdown]
# # PRACTICA 1
#
# ### Resuelve las siguientes preguntas empleando lo aprendido con las estructuras de Datos

# %% [markdown]
# Pon el código debajo de cada pregunta. Añade tantas celdas de código como necesites.

# %% [markdown]
# #### 1.- Escribe una ecuación que emplee multiplicación, división, un exponente, suma y resta y que sea igual a 100.25. (0,25 ptos)

# %%
# ecuacion que da como resultado = 100.25

# %%
resultado = (10**2 *2) / 2 + 1.5 - 1.25

# %%
print(resultado)
# Out:
# 100.25

# %% [markdown]
# #### 2.- ¿Qué harías para obtener la raíz cuadrada de 100? Busca dos formas. (0,5 ptos)

# %%
# forma 1

# %%
raiz1 = 100 ** 0.5

# %%
print("Raíz cuadrada con **:", raiz1)
# Out:
# Raíz cuadrada con **: 10.0

# %%
# forma 2

# %%
import math

# %%
raiz2 = math.sqrt(100)

# %%
print("Raíz cuadrada con math.sqrt:", raiz2)
# Out:
# Raíz cuadrada con math.sqrt: 10.0

# %% [markdown]
# #### 3.- ¿Y el cuadrado de 100? (0,25 ptos)

# %%
# cuadrado 100

# %%
cuadrado1 = 100 ** 2

# %%
print("Cuadrado con **:", cuadrado1)
# Out:
# Cuadrado con **: 10000

# %% [markdown]
# #### 4.- Tenemos la string 'hello'. (0,5 ptos)
# #### Primero devuelve la letra 'e'
# #### Luego dale la vuelta a la string
# #### Después usa dos métodos para devolver la letra 'o'

# %%
# definimos la string

# %%
texto = "hello"

# %%
# 1. Devolver la letra 'e' (indice 1)

# %%
print("Letra e:", texto[1])
# Out:
# Letra e: e

# %%
# 2. Darle la vuelta a la string

# %%
print("Texto invertido:", texto[::-1])
# Out:
# Texto invertido: olleh

# %%
# 3. Dos formas de devolver la letra 'o'

# %%
print("Letra o (con índice positivo):", texto[4])
# Out:
# Letra o (con índice positivo): o

# %%
print("Letra o (con índice negativo):", texto[-1])
# Out:
# Letra o (con índice negativo): o

# %% [markdown]
# #### 5.- Crear una lista que contenga esto [0,0,0] de dos formas distintas (0,5 ptos)

# %%
# Forma 1: escribirla directamente

# %%
lista1 = [0, 0, 0]

# %%
print("Lista 1:", lista1)
# Out:
# Lista 1: [0, 0, 0]

# %%
# Forma 2: usando multiplicación de listas

# %%
lista2 = [0] * 3

# %%
print("Lista 2:", lista2)
# Out:
# Lista 2: [0, 0, 0]

# %% [markdown]
# #### 6.- Reasigna 'hello' en la lista a continuación para que diga 'goodbye' (1 pto)

# %%
lista = [1,2,[3,4,'hello']]

# %%
lista[2][2] = 'goodbye'

# %%
print(lista)
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# #### 7.- Ordena la siguiente lista (0,5 ptos)

# %%
listaSinOrdenar = [5,3,4,6,1]

# %%
listaOrdenada1 = sorted(listaSinOrdenar)

# %%
print("Con sorted():", listaOrdenada1)
# Out:
# Con sorted(): [1, 3, 4, 5, 6]

# %% [markdown]
# #### 8.- En los siguientes diccionarios, extrae el valor de 'hello (2 ptos)

# %%
f = {'k1':{'k2':'hello'}}

# %%
print("f:", f['k1']['k2'])
# Out:
# f: hello

# %%
d = {'key1':'hello'}

# %%
print("d:", d['key1'])
# Out:
# d: hello

# %%
g = {'k1':[{'o1':['valor escondido',['hello']]}]}

# %%
print("g:", g['k1'][0]['o1'][1][0])
# Out:
# g: hello

# %%
h = {'k1':[1,2,{'k2':['complicado',{'dificil':[1,2,['hello']]}]}]}

# %%
print("h:", h['k1'][2]['k2'][1]['dificil'][2][0])
# Out:
# h: hello

# %% [markdown]
# #### 9.- Crea una tupla (1 pto)

# %%
mi_tupla = (1, 2, 3, 'hello')

# %%
print(mi_tupla)
# Out:
# (1, 2, 3, 'hello')

# %% [markdown]
# #### 10.- Emplea los sets para encontrar los valores únicos de esta lista (0,5 ptos)

# %%
listaDuplicada = [1,2,2,33,4,4,11,22,3,3,2]

# %%
# Convertir la lista a set para obtener valores únicos

# %%
valoresUnicos = set(listaDuplicada)

# %%
print(valoresUnicos)
# Out:
# {1, 2, 33, 4, 3, 11, 22}

# %% [markdown]
# #### 11.- Haz las siguientes comparaciones: (0,5 ptos)
# #### Dos mayor que tres
# #### Tres igual que 2
# #### La raíz cuadrada de cuatro no es igual a 2
# #### Se cumple si 6 es mayor que 5 y 7 menor de 8
# #### Se cumple si la longitud de _nombre_ es  que el número de elementos de _colores_ o si la longitud de _nombre_ es menor de 7.

# %%
# 2 mayor que 3

# %%
print("2 > 3:", 2 > 3)
# Out:
# 2 > 3: False

# %%
# 3 igual que 2

# %%
print("3 == 2:", 3 == 2)
# Out:
# 3 == 2: False

# %%
# raíz cuadrada de 4 no es igual a 2

# %%
import math

# %%
print("√4 != 2:", math.sqrt(4) != 2)
# Out:
# √4 != 2: False

# %%
# 6 mayor que 5 y 7 menos que 8

# %%
print("6>5 y 7<8:", 6 > 5 and 7 < 8)
# Out:
# 6>5 y 7<8: True

# %%
nombre = "Pepito"
colores = ["azul","rojo","verde","lila","amarillo limón"]

# %%
nombre = "Pepito"

# %%
colores = ["azul", "rojo", "verde", "lila", "amarillo limón"]

# %%
print("Condición nombre y colores:", len(nombre) == len(colores) or len(nombre) < 7)
# Out:
# Condición nombre y colores: True

# %% [markdown]
# #### 12.- Crea un archivo mediante código que se llame _tabla-nombres.txt_ y que esté formado por 4 columnas y 4 filas con la siguiente formación (1,5 ptos):
# #### Primera columna: Nombre
# #### Segunda columna: Apellidos (2 apellidos)
# #### Tercera columna: Edad
# #### Cuarta columna: Mascotas (nombre de la mascota si tienen)
#
# #### ¿Qué pasa si abres el archivo desde Jupyter y has metido acentos? ¿Puedes solucionarlo?

# %%
# datos

# %%
filas = [
    ["Juan", "Pérez Gómez", "28", "Firulais"],
    ["María", "López Díaz", "35", "Misu"],
    ["Carlos", "García Ruiz", "42", ""],
    ["Ana", "Sánchez Ortega", "30", "Rex"]
]

# %%
# archivo

# %%
with open("tabla-nombres.txt", "w", encoding="utf-8") as archivo:
    for fila in filas:
        archivo.write("\t".join(fila) + "\n")

# %%
print("Archivo creado correctamente")
# Out:
# Archivo creado correctamente

# %% [markdown]
# #### 13.- Crea un diccionario que contenga las siguientes parejas. Obtén el listado de keys() y guárdalo en una lista. Añade un par de elementos más y después convierte esa lista en un set (1 pto).
#
# #### Rattus = novergicus, rattus
# #### Glaucidium = brasilianum, hoskinsii, californicum, minutissimum
# #### Echinocactus = grusonii
# #### Opuntia = 1

# %%
# Crear el diccionario inicial

# %%
plantas = {
    "Rattus": ["novergicus", "rattus"],
    "Glaucidium": ["brasilianum", "hoskinsii", "californicum", "minutissimum"],
    "Echinocactus": ["grusonii"],
    "Opuntia": [1]
}

# %%
# Obtener las keys y guardarlas en una lista

# %%
keys_lista = list(plantas.keys())

# %%
print("Lista de keys:", keys_lista)
# Out:
# Lista de keys: ['Rattus', 'Glaucidium', 'Echinocactus', 'Opuntia']

# %%
# Añadir un par de elementos más al diccionario

# %%
plantas["Ficus"] = ["benjamina", "elastica"]

# %%
plantas["Aloe"] = ["vera"]

# %%
# Actualizar la lista de keys

# %%
keys_lista = list(plantas.keys())

# %%
print("Lista de keys actualizada:", keys_lista)
# Out:
# Lista de keys actualizada: ['Rattus', 'Glaucidium', 'Echinocactus', 'Opuntia', 'Ficus', 'Aloe']

# %%
# Convertir la lista en un set

# %%
keys_set = set(keys_lista)

# %%
print("Keys como set:", keys_set)
# Out:
# Keys como set: {'Ficus', 'Glaucidium', 'Aloe', 'Rattus', 'Opuntia', 'Echinocactus'}
